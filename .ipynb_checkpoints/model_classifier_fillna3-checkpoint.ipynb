# %%
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

#train_data_file = './train_data02.csv'
#train_data_file = './feature_importance/train_data_50.csv'
#train_data_file = './feature_importance/train_twoStep_50.csv'
train_data_file = 'D:/QQFILE/Server_User_model/dataset/trainFinal2_del.csv'
test_data_file = 'D:/QQFILE/Server_User_model/dataset/val_Final_data2.csv'
train_data = pd.read_csv(train_data_file, encoding='utf-8')
test_data = pd.read_csv(test_data_file, encoding='utf-8')

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', 10)
print(train_data.shape)
print(test_data.shape)
#print(test_data.shape)
train_data.head()
#print(train_data['dist_cnt_y1'].isnull().sum())
# Out:
# (23432, 154)
# (6675, 154)
#    pax_fcny  pax_tax  tkt_3y_amt  dist_cnt_y1  dist_cnt_y3  avg_dist_cnt_y2  \
# 0    2497.0   5059.0         3.0          NaN          NaN              NaN
# 1    1494.0   1544.0         3.0          NaN          NaN            835.0
# 2     214.0   2689.0         3.0          NaN          NaN              NaN
# 3    1287.0   4452.0      3644.0        391.0        947.0           2925.0
# 4     645.0   2287.0      3682.0          NaN       1588.0              NaN
#
#    tkt_avg_amt_y3  dist_i_cnt_y3  avg_dist_cnt_y3  pref_city_y3_3  \
# 0             3.0            NaN              NaN             NaN
# 1          5452.0            NaN            875.0             NaN
# 2             3.0            NaN              NaN             NaN
# 3          5925.0          573.0           3380.0             NaN
# 4             3.0          948.0              NaN            59.0
#
#    tkt_avg_amt_y2  tkt_i_amt_y3  pref_city_y3_2  dist_i_cnt_y2  \
# 0             4.0           3.0             NaN            NaN
# 1          4599.0        4642.0             NaN            NaN
# 2             4.0           3.0             NaN            NaN
# 3             4.0        4669.0            62.0            NaN
# 4             4.0           3.0            49.0          865.0
#
#    seat_walkway_cnt_y3  dist_all_cnt_y2  pref_month_y3_1  pref_city_y2_2  \
# 0                  NaN              NaN              NaN             NaN
# 1                  NaN              NaN              2.0             NaN
# 2                  NaN              NaN              NaN             NaN
# 3                  1.0              NaN             12.0             NaN
# 4                  4.0           1533.0              NaN            49.0
#
#    pref_line_y3_3  pref_city_y2_3  tkt_all_amt_y3  avg_dist_cnt_y1  \
# 0             NaN             NaN             3.0              NaN
# 1           264.0             NaN          4722.0           1051.0
# 2             NaN             NaN             3.0              NaN
# 3             NaN             NaN          4594.0              NaN
# 4             NaN            57.0             3.0              NaN
#
#    pref_month_y3_2  pref_line_y2_2  pref_line_y3_1  prebuy_i_cnt_y3_d99  \
# 0              NaN             NaN             NaN                  NaN
# 1              4.0           332.0           306.0                  NaN
# 2              NaN             NaN             NaN                  NaN
# 3              1.0             NaN            99.0                  2.0
# 4              NaN             NaN             NaN                  4.0
#
#    pref_line_y3_4  pref_line_y3_2  seg_route_to  ffp_nbr  pref_orig_y3_3  \
# 0             NaN             NaN           NaN      NaN             NaN
# 1             NaN           340.0           NaN      NaN            54.0
# 2             NaN             NaN           1.0      NaN             NaN
# 3             NaN           244.0           1.0      NaN             NaN
# 4             NaN             NaN           NaN     11.0             NaN
#
#    flt_bag_cnt_y3  tkt_i_amt_y2  seat_middle_cnt_y3  pref_line_y2_1  \
# 0             NaN           4.0                 NaN             NaN
# 1             NaN        3772.0                 NaN           305.0
# 2             NaN           4.0                 NaN             NaN
# 3             2.0           4.0                 NaN             NaN
# 4             4.0           4.0                 NaN             NaN
#
#    seat_window_cnt_y3  pref_orig_city_y2  pref_month_y2_1  pref_line_y2_3  \
# 0                 NaN                NaN              NaN             NaN
# 1                 2.0                NaN              2.0           238.0
# 2                 NaN                NaN              NaN             NaN
# 3                 1.0                NaN              NaN             NaN
# 4                 NaN               79.0              NaN             NaN
#
#    pref_line_y2_4  pref_month_y2_2  pref_month_y3_3  pref_orig_y3_2  \
# 0             NaN              NaN              NaN             NaN
# 1             NaN              4.0              NaN            52.0
# 2             NaN              NaN              NaN             NaN
# 3             NaN              NaN              NaN            62.0
# 4             NaN              NaN              NaN             NaN
#
#    tkt_all_amt_y2  age  flt_delay_time_m3  flt_delay_cnt_y3  pref_city_y1_2  \
# 0             4.0  NaN              833.0               NaN             NaN
# 1          3860.0  NaN              833.0               NaN             NaN
# 2             4.0  NaN              833.0               NaN             NaN
# 3             4.0  NaN              833.0               NaN             NaN
# 4             4.0  NaN              833.0               NaN             NaN
#
#    pref_city_y3_4  prebuy_i_cnt_y2_d99  pit_avg_amt_y3  seat_walkway_cnt_y2  \
# 0             NaN                  NaN             NaN                  NaN
# 1             NaN                  NaN             NaN                  NaN
# 2             NaN                  NaN             NaN                  NaN
# 3             NaN                  NaN             NaN                  NaN
# 4             NaN                  4.0             NaN                  4.0
#
#    nation_name  pref_orig_y2_2  pref_month_y2_3  flt_bag_cnt_y2  \
# 0          NaN             NaN              NaN             NaN
# 1          NaN            52.0              NaN             NaN
# 2          NaN             NaN              NaN             NaN
# 3          NaN             NaN              NaN             NaN
# 4          NaN             NaN              NaN             4.0
#
#    pref_month_y3_4  pit_all_amt  pit_avg_amt_y2  pit_accu_air_amt  \
# 0              NaN          7.0             NaN               NaN
# 1              NaN          7.0             NaN               NaN
# 2              NaN          7.0             NaN               NaN
# 3              NaN          7.0             NaN               NaN
# 4              NaN          7.0             NaN               NaN
#
#    cabin_y_cnt_y3  cabin_hy_cnt_y3  pref_line_y1_2  pit_next_level_dist  \
# 0             NaN              NaN             NaN                  2.0
# 1             NaN              NaN           196.0                  2.0
# 2             NaN              NaN             NaN                  2.0
# 3             2.0              NaN             NaN                  2.0
# 4             NaN              NaN             NaN                  2.0
#
#    flt_nature_cnt_y1  pref_city_y2_4  dist_all_cnt_y1  pref_orig_y2_3  \
# 0                NaN             NaN              NaN             NaN
# 1                NaN             NaN              NaN            54.0
# 2                NaN             NaN              NaN             NaN
# 3                1.0             NaN              NaN             NaN
# 4                NaN             NaN              NaN             NaN
#
#    dist_d_cnt_y3  pit_avg_accu_amt_y3  tkt_avg_amt_y1  flt_delay_time_y2  \
# 0            NaN                  NaN             NaN              612.0
# 1           80.0                  NaN          2094.0              612.0
# 2            NaN                  NaN             NaN              612.0
# 3            NaN                  NaN             NaN              612.0
# 4            NaN                  NaN             NaN              612.0
#
#    pit_avg_interval_y2  pref_city_y1_1  pref_line_y3_5  mdl_mcv  \
# 0                  NaN             NaN             NaN      NaN
# 1                  NaN             NaN             NaN      5.0
# 2                  NaN             NaN             NaN      NaN
# 3                  NaN             NaN             NaN      5.0
# 4                  NaN             NaN             NaN      NaN
#
#    dist_i_cnt_y1  dist_all_cnt_y3  pit_accu_air_cnt  gender  tkt_book_cnt_y3  \
# 0            NaN              NaN               NaN     NaN              NaN
# 1            NaN              NaN               NaN     NaN              NaN
# 2            NaN              NaN               NaN     NaN              NaN
# 3            NaN            947.0               NaN     NaN              NaN
# 4            NaN           1588.0               NaN     2.0              NaN
#
#    mdl_influence  flt_nature_cnt_y3  seat_middle_cnt_y2  select_seat_cnt_y2  \
# 0            NaN                NaN                 NaN                 NaN
# 1            NaN                NaN                 NaN                 NaN
# 2            NaN                NaN                 NaN                 NaN
# 3            NaN                2.0                 NaN                 NaN
# 4            NaN                4.0                 NaN                 NaN
#
#    flt_leg_i_cnt_y3  avg_dist_cnt_m6  tkt_d_amt_y3  pref_city_y1_3  \
# 0               NaN              NaN           NaN             NaN
# 1               NaN              NaN        1124.0             NaN
# 2               NaN              NaN           NaN             NaN
# 3               2.0              NaN           NaN             NaN
# 4               4.0              NaN           NaN             NaN
#
#    pref_month_y3_5  cabin_y_cnt_y2  pref_orig_city_y3  pit_accu_amt_y3  \
# 0              NaN             NaN                NaN              NaN
# 1              NaN             NaN                NaN              NaN
# 2              NaN             NaN                NaN              NaN
# 3              NaN             NaN               50.0              NaN
# 4              NaN             NaN               77.0              NaN
#
#    prebuy_i_cnt_y3_d30  prebuy_i_cnt_y3_d3  flt_delay_time_m6  \
# 0                  NaN                 NaN              799.0
# 1                  NaN                 NaN              799.0
# 2                  NaN                 NaN              799.0
# 3                  NaN                 NaN              799.0
# 4                  NaN                 NaN              799.0
#
#    pref_month_y2_4  prebuy_d_cnt_y3_d99  pit_accu_amt_y2  pit_avg_interval_y3  \
# 0              NaN                  NaN              NaN                  NaN
# 1              NaN                  NaN              NaN                  NaN
# 2              NaN                  NaN              NaN                  NaN
# 3              NaN                  NaN              NaN                  NaN
# 4              NaN                  NaN              NaN                  NaN
#
#    seg_cabin  tkt_avg_interval_y3  flt_delay_time_y3  pref_month_y1_1  \
# 0        2.0                  NaN                NaN              NaN
# 1        2.0                  NaN                NaN              2.0
# 2        4.0                  NaN                NaN              NaN
# 3        4.0                  NaN                NaN              NaN
# 4        4.0                  NaN                NaN              NaN
#
#    dist_i_cnt_m6  pref_line_y1_3  pit_add_air_amt_y3  pref_month_y2_5  \
# 0            NaN             NaN                 NaN              NaN
# 1            NaN             NaN                 NaN              NaN
# 2            NaN             NaN                 NaN              NaN
# 3            NaN             NaN                 NaN              NaN
# 4            NaN             NaN                 NaN              NaN
#
#    flt_leg_cnt_y2  pit_accu_amt_y1  flt_delay_cnt_y2  pit_avg_accu_amt_y2  \
# 0             NaN              NaN               NaN                  NaN
# 1             NaN              NaN               NaN                  NaN
# 2             NaN              NaN               NaN                  NaN
# 3             NaN              NaN               NaN                  NaN
# 4             4.0              NaN               NaN                  NaN
#
#    pref_city_y3_1  dist_all_cnt_m6  seat_window_cnt_y2  flt_cnt_y3  \
# 0             NaN              NaN                 NaN         NaN
# 1             NaN              NaN                 2.0         3.0
# 2             NaN              NaN                 NaN         NaN
# 3            46.0              NaN                 NaN         2.0
# 4            46.0              NaN                 NaN         NaN
#
#    pref_line_y1_1  pref_orig_y3_1  flt_bag_cnt_y1  flt_leg_i_cnt_y2  \
# 0             NaN             NaN             NaN               NaN
# 1           271.0            44.0             NaN               NaN
# 2             NaN             NaN             NaN               NaN
# 3             NaN            44.0             NaN               NaN
# 4             NaN             NaN             NaN               4.0
#
#    prebuy_d_cnt_y2_d99  tkt_d_amt_y2  flt_delay_time_y1  tkt_avg_interval_y2  \
# 0                  NaN           1.0              774.0                  NaN
# 1                  NaN         932.0              774.0                  NaN
# 2                  NaN           1.0              774.0                  NaN
# 3                  NaN           1.0              774.0                  NaN
# 4                  NaN           1.0              774.0                  NaN
#
#    dist_d_cnt_y2  pref_orig_y1_1  cabin_hy_cnt_y2  pref_orig_city_y1  \
# 0            NaN             NaN              NaN                NaN
# 1           78.0            52.0              NaN                NaN
# 2            NaN             NaN              NaN                NaN
# 3            NaN             NaN              NaN                NaN
# 4            NaN             NaN              NaN                NaN
#
#    cabin_hf_cnt_m6  pref_orig_y3_4  pref_dest_city_y3  pit_accu_non_amt  \
# 0              NaN             NaN                NaN               NaN
# 1              NaN             NaN               54.0               NaN
# 2              NaN             NaN                NaN               NaN
# 3              NaN             NaN               43.0               NaN
# 4              NaN             NaN                NaN               NaN
#
#    tkt_book_cnt_y2  tkt_i_amt_y1  pref_city_y2_5  tkt_all_amt_y1  \
# 0              NaN           NaN             NaN             NaN
# 1              NaN        1524.0             NaN          1609.0
# 2              NaN           NaN             NaN             NaN
# 3              NaN           NaN             NaN             NaN
# 4              NaN           NaN             NaN             NaN
#
#    pref_city_y2_1  residence_country  pref_orig_y2_4  pit_add_air_amt_y2  \
# 0             NaN                NaN             NaN                 NaN
# 1             NaN                NaN             NaN                 NaN
# 2             NaN                NaN             NaN                 NaN
# 3             NaN                NaN             NaN                 NaN
# 4            51.0                1.0             NaN                 NaN
#
#    prebuy_i_cnt_y3_d14  pref_orig_y1_2  tkt_return_cnt_y3  \
# 0                  NaN             NaN                NaN
# 1                  NaN            45.0                NaN
# 2                  NaN             NaN                NaN
# 3                  NaN             NaN                NaN
# 4                  NaN             NaN                NaN
#
#    pit_avg_accu_amt_y1  pref_line_y2_5  pit_cons_amt_y3  prebuy_i_cnt_y2_d30  \
# 0                  NaN             NaN              NaN                  NaN
# 1                  NaN             NaN              NaN                  NaN
# 2                  NaN             NaN              NaN                  NaN
# 3                  NaN             NaN              NaN                  NaN
# 4                  NaN             NaN              NaN                  NaN
#
#    pref_orig_y3_5  pit_avg_amt_y1  pref_orig_city_m6  emd_lable2  emd_lable  \
# 0             NaN             NaN                NaN           0          0
# 1             NaN             NaN                NaN           0          1
# 2             NaN             NaN                NaN           0          1
# 3             NaN             NaN                NaN           0          0
# 4             NaN             NaN                NaN           1          1
#
#                            pax_name                      pax_passport
# 0  9612c51f08718e48b1361e415ef55be9  93d0aceeaef3f85264e5c5b5b1148a90
# 1  c7ca533cd9da4c4bf3d597248f90bc6e  6930f6fa59d86c11fa28c610ab6f56a5
# 2  bd2cb6b0dd56fb3de6f7c018296a07e2  da73afa8f6ededd29d67a9331dccdbe9
# 3  65657872fe131ea7651565638dcb5683  dc31eead23771810dbb586ad236ade3b
# 4  722261f7b860b183da9fe0b6630b6dbf  7689603247539830a08d945cb1a57823

# %%
#train_data['dist_cnt_y1'].replace(0, '', inplace = True)
features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable', 'emd_lable2']]
#features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable2']]
#features_columns_test = [col for col in test_data.columns ]
# print(Data.shape)

train = train_data[features_columns].values
target =train_data['emd_lable2'].values
# target2 =train_data['emd_lable'].values

# %%
# from sklearn.feature_selection import SelectKBest
# from array import array
# from sklearn.feature_selection import chi2

# train = SelectKBest(chi2, k=71).fit_transform(train, target)
# print(train.shape)

# train = pd.DataFrame(train)
# train.head(5)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.3, random_state=0)
print(X_train.shape,y_train.shape,y_test.shape)
# Out:
# (16402, 150) (16402,) (7030,)

# %%
y_train = y_train.reshape((16402,1))
# y_train = y_train.reshape((16402,1))
z = np.zeros(7030)
z = z.reshape(7030,1)
Data = X_train
Data = np.hstack((X_train,y_train))
Data2 = np.hstack((X_test,z))
print(Data.shape,Data2.shape)
for i in range(len(Data2)):
    Data2[i][150] = float('nan')
print(Data.shape,Data2.shape)
# Out:
# (16402, 151) (7030, 151)
# (16402, 151) (7030, 151)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer()
imp.fit(Data,None)
Data = imp.transform(Data)
Data2 = imp.transform(Data2)
# train_data[category_fea] = Data
#train_data.head()
#按照平均数填充数值型特征
# for col in numerical_fea:
#     List = train_data[col]
#     List2 = []
#     for i in List:
#         if i == i:
#             List2.append(i)
#     List2 = np.array(List2)
#     from scipy import stats
#     x = stats.mode(List2)[0][0]
#     train_data[col] = train_data[col].fillna(x)
    
#     train_data[numerical_fea] = train_data[numerical_fea].fillna(train_data[numerical_fea].median())
#data_test_a[numerical_fea] = data_test_a[numerical_fea].fillna(data_train[numerical_fea].median())

#按照众数填充类别型特征
# train_data[category_fea] = train_data[category_fea].fillna(train_data[category_fea].median())
#data_test_a[category_fea] = data_test_a[category_fea].fillna(data_train[category_fea].mode())

# %%
features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable', 'emd_lable2']]
#features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable2']]
#features_columns_test = [col for col in test_data.columns ]
print(Data.shape)
train = Data
target =train_data['emd_lable2'].values

print(train.shape)
# print(train_data[features_columns].values.shape)
# print(target.sum())

for i in range(len(train)):
    for j in range(150):
        if train[i][j]<0:
            train[i][j] = 0

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

clf = RandomForestClassifier(n_estimators=500, 
                             max_depth=71, 
                             random_state=0, 
                             n_jobs=-1)
# from catboost import CatBoostClassifier
# clf = CatBoostClassifier(iterations=300,
#                 depth=12,
#                 random_seed=0,
#                 thread_count=-1,
#                 learning_rate = 0.4,
#                 task_type="GPU",
#                 loss_function = "CrossEntropy",
#                 #nan_mode= "Max"
#             )




print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
#print(test.shape, target_test.shape)

#验证集
clf = clf.fit(X_train, y_train)
#clf = clf.fit(X_train, y_train,plot=True)
print('=======')
y_true, y_pred = y_test, clf.predict(X_test)
#print(y_pred)
print(classification_report(y_true, y_pred))
print("RandomForest:", clf.score(X_test, y_test))
print('=======')

#print(clf.predict(X_test))

#设定阈值
threshold = 0.53

predicted_proba = clf.predict_proba(X_test)
print(predicted_proba.shape)
predicted = (predicted_proba [:,1] >= threshold).astype('int')#
accuracy = accuracy_score(y_test, predicted)
print(classification_report(y_test, predicted))
print("accuracy: ", accuracy)

pred_1d = predicted_proba[:,1].reshape(7030,)
y_test = y_test.reshape(7030,)
print(pred_1d.shape, y_test.shape)
print("AUC: ",roc_auc_score(y_true, pred_1d))


print(predicted.shape)
#predicted.reshape(9373,2)
data1 = predicted_proba.reshape(7030,2)

#print(train.shape, target.shape)
#print(test.shape, target_test.shape)
# Out:
# (16402, 71) (16402,)
# (7030, 71) (7030,)
# =======
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6621
#            1       0.94      0.38      0.54       409
#
#     accuracy                           0.96      7030
#    macro avg       0.95      0.69      0.76      7030
# weighted avg       0.96      0.96      0.95      7030
#
# RandomForest: 0.9624466571834993
# =======
# (7030, 2)
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6621
#            1       0.95      0.36      0.53       409
#
#     accuracy                           0.96      7030
#    macro avg       0.96      0.68      0.75      7030
# weighted avg       0.96      0.96      0.95      7030
#
# accuracy:  0.961877667140825
# (7030,) (7030,)
# AUC:  0.9261612584098385
# (7030,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# clf = RandomForestClassifier(n_estimators=500, 
#                              max_depth=71, 
#                              random_state=0, 
#                              n_jobs=-1)
from catboost import CatBoostClassifier
clf = CatBoostClassifier(iterations=300,
                depth=12,
                random_seed=0,
                thread_count=-1,
                learning_rate = 0.4,
                task_type="GPU",
                loss_function = "CrossEntropy",
                #nan_mode= "Max"
            )


X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.3, random_state=0)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
#print(test.shape, target_test.shape)

#验证集
clf = clf.fit(X_train, y_train)
#clf = clf.fit(X_train, y_train,plot=True)
print('=======')
y_true, y_pred = y_test, clf.predict(X_test)
#print(y_pred)
print(classification_report(y_true, y_pred))
print("RandomForest:", clf.score(X_test, y_test))
print('=======')

#print(clf.predict(X_test))

#设定阈值
threshold = 0.53

predicted_proba = clf.predict_proba(X_test)
print(predicted_proba.shape)
predicted = (predicted_proba [:,1] >= threshold).astype('int')#
accuracy = accuracy_score(y_test, predicted)
print(classification_report(y_test, predicted))
print("accuracy: ", accuracy)

pred_1d = predicted_proba[:,1].reshape(7030,)
y_test = y_test.reshape(7030,)
print(pred_1d.shape, y_test.shape)
print("AUC: ",roc_auc_score(y_true, pred_1d))


print(predicted.shape)
#predicted.reshape(9373,2)
data1 = predicted_proba.reshape(7030,2)

#print(train.shape, target.shape)
#print(test.shape, target_test.shape)
# Out:
# (16402, 71) (16402,)
# (7030, 71) (7030,)
# 0:	learn: 0.2773854	total: 301ms	remaining: 1m 29s
# 1:	learn: 0.1806290	total: 391ms	remaining: 58.3s
# 2:	learn: 0.1394439	total: 488ms	remaining: 48.3s
# 3:	learn: 0.1137941	total: 580ms	remaining: 42.9s
# 4:	learn: 0.0988653	total: 666ms	remaining: 39.3s
# 5:	learn: 0.0898923	total: 751ms	remaining: 36.8s
# 6:	learn: 0.0848827	total: 831ms	remaining: 34.8s
# 7:	learn: 0.0756586	total: 928ms	remaining: 33.9s
# 8:	learn: 0.0658725	total: 1.01s	remaining: 32.8s
# 9:	learn: 0.0609627	total: 1.1s	remaining: 32s
# 10:	learn: 0.0545237	total: 1.19s	remaining: 31.3s
# 11:	learn: 0.0512110	total: 1.27s	remaining: 30.6s
# 12:	learn: 0.0479322	total: 1.36s	remaining: 30s
# 13:	learn: 0.0455769	total: 1.44s	remaining: 29.3s
# 14:	learn: 0.0429438	total: 1.51s	remaining: 28.7s
# 15:	learn: 0.0387398	total: 1.6s	remaining: 28.5s
# 16:	learn: 0.0354322	total: 1.69s	remaining: 28.1s
# 17:	learn: 0.0337570	total: 1.77s	remaining: 27.7s
# 18:	learn: 0.0303540	total: 1.87s	remaining: 27.6s
# 19:	learn: 0.0295679	total: 1.95s	remaining: 27.3s
# 20:	learn: 0.0274193	total: 2.04s	remaining: 27.1s
# 21:	learn: 0.0250615	total: 2.13s	remaining: 26.9s
# 22:	learn: 0.0233146	total: 2.22s	remaining: 26.7s
# 23:	learn: 0.0217840	total: 2.31s	remaining: 26.5s
# 24:	learn: 0.0208648	total: 2.39s	remaining: 26.3s
# 25:	learn: 0.0197777	total: 2.47s	remaining: 26.1s
# 26:	learn: 0.0181702	total: 2.58s	remaining: 26s
# 27:	learn: 0.0165909	total: 2.67s	remaining: 26s
# 28:	learn: 0.0158054	total: 2.76s	remaining: 25.8s
# 29:	learn: 0.0151998	total: 2.84s	remaining: 25.5s
# 30:	learn: 0.0142808	total: 2.94s	remaining: 25.5s
# 31:	learn: 0.0137142	total: 3.02s	remaining: 25.3s
# 32:	learn: 0.0132783	total: 3.1s	remaining: 25.1s
# 33:	learn: 0.0124383	total: 3.2s	remaining: 25s
# 34:	learn: 0.0119279	total: 3.28s	remaining: 24.8s
# 35:	learn: 0.0115175	total: 3.36s	remaining: 24.6s
# 267:	learn: 0.0006695	total: 23s	remaining: 2.74s
# 268:	learn: 0.0006665	total: 23s	remaining: 2.65s
# 269:	learn: 0.0006640	total: 23.1s	remaining: 2.57s
# 270:	learn: 0.0006610	total: 23.2s	remaining: 2.48s
# 271:	learn: 0.0006589	total: 23.3s	remaining: 2.4s
# 272:	learn: 0.0006543	total: 23.4s	remaining: 2.31s
# 273:	learn: 0.0006521	total: 23.4s	remaining: 2.22s
# 274:	learn: 0.0006495	total: 23.5s	remaining: 2.14s
# 275:	learn: 0.0006461	total: 23.6s	remaining: 2.05s
# 276:	learn: 0.0006430	total: 23.7s	remaining: 1.97s
# 277:	learn: 0.0006411	total: 23.8s	remaining: 1.88s
# 278:	learn: 0.0006380	total: 23.9s	remaining: 1.8s
# 279:	learn: 0.0006344	total: 24s	remaining: 1.71s
# 280:	learn: 0.0006309	total: 24s	remaining: 1.63s
# 281:	learn: 0.0006283	total: 24.1s	remaining: 1.54s
# 282:	learn: 0.0006258	total: 24.2s	remaining: 1.45s
# 283:	learn: 0.0006240	total: 24.3s	remaining: 1.37s
# 284:	learn: 0.0006213	total: 24.4s	remaining: 1.28s
# 285:	learn: 0.0006180	total: 24.5s	remaining: 1.2s
# 286:	learn: 0.0006159	total: 24.5s	remaining: 1.11s
# 287:	learn: 0.0006138	total: 24.6s	remaining: 1.02s
# 288:	learn: 0.0006111	total: 24.7s	remaining: 940ms
# 289:	learn: 0.0006094	total: 24.8s	remaining: 855ms
# 290:	learn: 0.0006079	total: 24.9s	remaining: 769ms
# 291:	learn: 0.0006054	total: 25s	remaining: 684ms
# 292:	learn: 0.0006028	total: 25s	remaining: 598ms
# 293:	learn: 0.0006009	total: 25.1s	remaining: 513ms
# 294:	learn: 0.0005984	total: 25.2s	remaining: 427ms
# 295:	learn: 0.0005971	total: 25.3s	remaining: 342ms
# 296:	learn: 0.0005949	total: 25.4s	remaining: 256ms
# 297:	learn: 0.0005923	total: 25.4s	remaining: 171ms
# 298:	learn: 0.0005900	total: 25.5s	remaining: 85.4ms
# 299:	learn: 0.0005880	total: 25.6s	remaining: 0us
# =======
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6621
#            1       0.91      0.48      0.63       409
#
#     accuracy                           0.97      7030
#    macro avg       0.94      0.74      0.81      7030
# weighted avg       0.97      0.97      0.96      7030
#
# RandomForest: 0.9669985775248933
# =======
# (7030, 2)
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6621
#            1       0.91      0.47      0.62       409
#
#     accuracy                           0.97      7030
#    macro avg       0.94      0.73      0.80      7030
# weighted avg       0.96      0.97      0.96      7030
#
# accuracy:  0.9665718349928877
# (7030,) (7030,)
# AUC:  0.925894455258127
# (7030,)

# %%
def find_repeat_data(name_list):
    """
    查找列表中重复的数据
    :param name_list: 
    :return: 一个重复数据的列表，列表中字典的key 是重复的数据，value 是重复的次数
    """
    repeat_list = []
    for i in set(name_list):
        ret=name_list.count(i) # 查找该数据在原列表中的个数
        if ret > 1:
            item=dict()
            item[i] = ret
            repeat_list.append(item)
    print(repeat_list)
    return repeat_list

find_repeat_data(list(y_test))
find_repeat_data(list(predicted))
#find_repeat_data(list())
# Out:
# [{0: 6621}, {1: 409}]
# [{0: 6818}, {1: 212}]
# [{0: 6818}, {1: 212}]

# %%
print(type(data1))
print(data1.shape)
print(pred_1d.shape)
#print(data2)
df = pd.DataFrame(data1)
df.insert(2, 'answer', list(y_test))  # 2表示插入列的位置（索引）， 'answer'是列标题
print(type(df))
print(df)
#df.to_csv('output_classifier.csv')
# Out:
# <class 'numpy.ndarray'>
# (7030, 2)
# (7030,)
# <class 'pandas.core.frame.DataFrame'>
#              0             1  answer
# 0     0.999741  2.589950e-04       0
# 1     0.999998  2.040955e-06       0
# 2     0.999861  1.388283e-04       0
# 3     0.996064  3.936086e-03       0
# 4     0.996728  3.272392e-03       0
# 5     0.999816  1.842845e-04       0
# 6     0.999998  1.798949e-06       0
# 7     0.999949  5.074947e-05       0
# 8     0.999961  3.930997e-05       0
# 9     0.999903  9.705287e-05       0
# 10    0.000492  9.995076e-01       1
# 11    0.999995  4.855793e-06       0
# 12    0.999992  8.236666e-06       0
# 13    0.999674  3.256507e-04       0
# 14    0.999905  9.450055e-05       0
# 15    0.999998  2.134063e-06       0
# 16    0.999601  3.986103e-04       0
# 17    0.988940  1.106023e-02       0
# 18    0.997210  2.790230e-03       0
# 19    0.979366  2.063408e-02       0
# 20    0.999942  5.792688e-05       0
# 21    0.996657  3.343134e-03       0
# 22    0.999851  1.493418e-04       0
# 23    1.000000  4.111205e-07       0
# 24    0.999909  9.064831e-05       0
# 25    0.999657  3.434887e-04       0
# 26    0.999963  3.743538e-05       0
# 27    0.999976  2.380488e-05       0
# 28    0.999961  3.861592e-05       0
# 29    0.999844  1.562757e-04       0
# ...        ...           ...     ...
# 7000  0.999961  3.861592e-05       0
# 7001  0.999495  5.053533e-04       0
# 7002  0.997529  2.470886e-03       0
# 7003  0.999862  1.378465e-04       0
# 7004  0.997737  2.263374e-03       0
# 7005  0.984122  1.587803e-02       0
# 7006  0.999986  1.441959e-05       0
# 7007  0.981949  1.805145e-02       0
# 7008  0.999910  9.035799e-05       0
# 7009  0.998383  1.617384e-03       0
# 7010  0.999997  2.940221e-06       0
# 7011  0.999971  2.854133e-05       0
# 7012  0.999081  9.194717e-04       0
# 7013  0.999942  5.840087e-05       0
# 7014  0.999988  1.231446e-05       0
# 7015  0.998832  1.167530e-03       0
# 7016  0.014247  9.857531e-01       1
# 7017  0.999977  2.315722e-05       0
# 7018  0.999996  3.749118e-06       0
# 7019  0.827804  1.721961e-01       0
# 7020  0.999509  4.905587e-04       0
# 7021  0.999994  5.642179e-06       0
# 7022  0.992445  7.555206e-03       0
# 7023  0.999913  8.662835e-05       0
# 7024  0.999763  2.373463e-04       0
# 7025  1.000000  3.155056e-07       0
# 7026  0.999511  4.891838e-04       0
# 7027  0.992475  7.525399e-03       0
# 7028  0.999995  4.938487e-06       0
# 7029  0.999663  3.369539e-04       0
#
# [7030 rows x 3 columns]
