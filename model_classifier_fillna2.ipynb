# %%
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

#train_data_file = './train_data02.csv'
#train_data_file = './feature_importance/train_data_50.csv'
#train_data_file = './feature_importance/train_twoStep_50.csv'
train_data_file = 'D:/QQFILE/Server_User_model/dataset/trainFinal2_del.csv'
test_data_file = 'D:/QQFILE/Server_User_model/dataset/val_Final_data2.csv'
train_data = pd.read_csv(train_data_file, encoding='utf-8')
test_data = pd.read_csv(test_data_file, encoding='utf-8')

# %%
#train_data['dist_cnt_y1'].replace(0, '', inplace = True)

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', 10)
print(train_data.shape)
print(test_data.shape)
#print(test_data.shape)
train_data.head()
#print(train_data['dist_cnt_y1'].isnull().sum())
# Out:
# (23432, 154)
# (6675, 154)
#    pax_fcny  pax_tax  tkt_3y_amt  dist_cnt_y1  dist_cnt_y3  avg_dist_cnt_y2  \
# 0    2497.0   5059.0         3.0          NaN          NaN              NaN
# 1    1494.0   1544.0         3.0          NaN          NaN            835.0
# 2     214.0   2689.0         3.0          NaN          NaN              NaN
# 3    1287.0   4452.0      3644.0        391.0        947.0           2925.0
# 4     645.0   2287.0      3682.0          NaN       1588.0              NaN
#
#    tkt_avg_amt_y3  dist_i_cnt_y3  avg_dist_cnt_y3  pref_city_y3_3  \
# 0             3.0            NaN              NaN             NaN
# 1          5452.0            NaN            875.0             NaN
# 2             3.0            NaN              NaN             NaN
# 3          5925.0          573.0           3380.0             NaN
# 4             3.0          948.0              NaN            59.0
#
#    tkt_avg_amt_y2  tkt_i_amt_y3  pref_city_y3_2  dist_i_cnt_y2  \
# ...

# %%
numerical_feature ="""pref_city_y3_3\tpref_city_y3_2\tpref_city_y2_2	pref_line_y3_3\tpref_city_y2_3\tpref_line_y2_2	pref_line_y3_1\tpref_line_y3_4	pref_line_y3_2	seg_route_to\tpref_orig_y3_3\tpref_line_y2_1\tpref_orig_city_y2\tpref_line_y2_3	pref_line_y2_4\tpref_orig_y3_2\tpref_city_y1_2	pref_city_y3_4\tnation_name	pref_orig_y2_2\tpref_line_y1_2\tpref_orig_y2_3\tpref_city_y1_1	pref_line_y3_5\tgender\tpref_city_y1_3\tpref_orig_city_y3\tseg_cabin\tpref_line_y1_3\tpref_city_y3_1\tpref_line_y1_1	pref_orig_y3_1\tpref_orig_y1_1\tpref_orig_city_y1\tpref_orig_y3_4	pref_dest_city_y3\tpref_city_y2_1	residence_country\tpref_orig_y2_4\tpref_orig_y1_2\tpref_line_y2_5\tpref_orig_y3_5\tpref_orig_city_m6"""
numerical_fea = numerical_feature.split('\t')
print(len(numerical_fea))
# numerical_fea.append('pax_name')
# numerical_fea.append('pax_passport')
# numerical_fea.append('emd_lable')
# numerical_fea.append('emd_lable2')

category_fea = [col for col in train_data.columns if col not in ['pax_name','pax_passport', 'emd_lable', 'emd_lable2']]
#category_fea = category_feature.split('\t')
print(len(category_fea))
Data = train_data[category_fea]
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer()
imp.fit(Data,None)
Data = imp.transform(Data)
# train_data[category_fea] = Data
#train_data.head()
#按照平均数填充数值型特征
# for col in numerical_fea:
#     List = train_data[col]
#     List2 = []
#     for i in List:
#         if i == i:
#             List2.append(i)
#     List2 = np.array(List2)
#     from scipy import stats
#     x = stats.mode(List2)[0][0]
#     train_data[col] = train_data[col].fillna(x)
    
#     train_data[numerical_fea] = train_data[numerical_fea].fillna(train_data[numerical_fea].median())
#data_test_a[numerical_fea] = data_test_a[numerical_fea].fillna(data_train[numerical_fea].median())

#按照众数填充类别型特征
# train_data[category_fea] = train_data[category_fea].fillna(train_data[category_fea].median())
#data_test_a[category_fea] = data_test_a[category_fea].fillna(data_train[category_fea].mode())
# Out:
# 43
# 150
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)

# %%
print(Data[0])
# Out:
# [ 2.49700000e+03  5.05900000e+03  3.00000000e+00  1.21208403e+04
#   1.76082653e+03  1.54674533e+03  3.00000000e+00 -7.86835979e+05
#   1.20728595e+03  4.00810665e+03  4.00000000e+00  3.00000000e+00
#   7.40839135e+01  7.84997905e+06  4.71861652e+00  2.83421386e+06
#  -4.28271722e+02  7.62868301e+01  2.08053608e+02  1.48955345e+03
#   3.00000000e+00  6.28111676e+02  8.55963565e+00 -1.22124662e+02
#  -1.12520706e+02  3.61804032e+00  1.97249183e+02 -5.33466322e+02
#   1.37739671e+00  1.54464604e+01  1.09289284e+02  4.72768806e+00
#   4.00000000e+00  1.87826886e+00  1.32608297e+02  2.65809050e-01
#   7.26365817e+01  8.62578342e+00  1.09308844e+02  2.69581493e+02
#   7.42366653e+00 -1.41248352e+01  1.02855898e+02  4.00000000e+00
#   5.20434652e+00  8.33000000e+02  1.70733612e+00 -4.21770005e+04
#   2.69489190e+03  3.59250631e+00  8.64943069e+02  3.14434156e+00
#   4.50096214e+01  2.88915104e+01 -6.97848681e+01  4.24813407e+00
# ...

# %%
features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable', 'emd_lable2']]
#features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable2']]
#features_columns_test = [col for col in test_data.columns ]
print(Data.shape)
train = Data
target =train_data['emd_lable2'].values

print(train.shape)
# print(train_data[features_columns].values.shape)
# print(target.sum())

for i in range(len(train)):
    for j in range(150):
        if train[i][j]<0:
            train[i][j] = 0
# Out:
# (23432, 150)
# (23432, 150)

# %%
from sklearn.feature_selection import SelectKBest
from array import array
from sklearn.feature_selection import chi2

train = SelectKBest(chi2, k=71).fit_transform(train, target)
print(train.shape)

train = pd.DataFrame(train)
train.head(5)
# Out:
# (23432, 71)
#        0       1       2             3            4            5       6   \
# 0  2497.0  5059.0     3.0  12120.840340  1760.826528  1546.745327     3.0
# 1  1494.0  1544.0     3.0  10317.074143  1760.821392   835.000000  5452.0
# 2   214.0  2689.0     3.0  17040.177560  1760.845312  1715.387773     3.0
# 3  1287.0  4452.0  3644.0    391.000000   947.000000  2925.000000  5925.0
# 4   645.0  2287.0  3682.0    934.866078  1588.000000  1853.848320     3.0
#
#       7            8            9       10      11            12  \
# 0    0.0  1207.285948  4008.106649     4.0     3.0  7.849979e+06
# 1    0.0   875.000000  3542.320905  4599.0  4642.0  6.916923e+06
# 2    0.0  1635.318248  5719.948767     4.0     3.0  1.126601e+07
# 3  573.0  3380.000000    66.718042     4.0  4669.0  0.000000e+00
# 4  948.0  1832.070352    59.000000     4.0     3.0  8.650000e+02
#
#              13    14          15           16      17           18  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

clf = RandomForestClassifier(n_estimators=500, 
                             max_depth=71, 
                             random_state=0, 
                             n_jobs=-1)
# from catboost import CatBoostClassifier
# clf = CatBoostClassifier(iterations=300,
#                 depth=12,
#                 random_seed=0,
#                 thread_count=-1,
#                 learning_rate = 0.4,
#                 task_type="GPU",
#                 loss_function = "CrossEntropy",
#                 #nan_mode= "Max"
#             )


X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.3, random_state=0)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
#print(test.shape, target_test.shape)

#验证集
clf = clf.fit(X_train, y_train)
#clf = clf.fit(X_train, y_train,plot=True)
print('=======')
y_true, y_pred = y_test, clf.predict(X_test)
#print(y_pred)
print(classification_report(y_true, y_pred))
print("RandomForest:", clf.score(X_test, y_test))
print('=======')

#print(clf.predict(X_test))

#设定阈值
threshold = 0.53

predicted_proba = clf.predict_proba(X_test)
print(predicted_proba.shape)
predicted = (predicted_proba [:,1] >= threshold).astype('int')#
accuracy = accuracy_score(y_test, predicted)
print(classification_report(y_test, predicted))
print("accuracy: ", accuracy)

pred_1d = predicted_proba[:,1].reshape(7030,)
y_test = y_test.reshape(7030,)
print(pred_1d.shape, y_test.shape)
print("AUC: ",roc_auc_score(y_true, pred_1d))


print(predicted.shape)
#predicted.reshape(9373,2)
data1 = predicted_proba.reshape(7030,2)

#print(train.shape, target.shape)
#print(test.shape, target_test.shape)
# Out:
# (16402, 71) (16402,)
# (7030, 71) (7030,)
# ...
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6621
#            1       0.71      0.17      0.28       409
#
#     accuracy                           0.95      7030
#    macro avg       0.83      0.58      0.62      7030
# weighted avg       0.94      0.95      0.93      7030
#
# RandomForest: 0.9477951635846372
# ...
# (7030, 2)
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6621
#            1       0.74      0.17      0.27       409
#
#     accuracy                           0.95      7030
#    macro avg       0.84      0.58      0.62      7030
# weighted avg       0.94      0.95      0.93      7030
#
# accuracy:  0.9480796586059744
# (7030,) (7030,)
# AUC:  0.7687736176180924
# (7030,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# clf = RandomForestClassifier(n_estimators=500, 
#                              max_depth=71, 
#                              random_state=0, 
#                              n_jobs=-1)
from catboost import CatBoostClassifier
clf = CatBoostClassifier(iterations=300,
                depth=12,
                random_seed=0,
                thread_count=-1,
                learning_rate = 0.4,
                task_type="GPU",
                loss_function = "CrossEntropy",
                #nan_mode= "Max"
            )


X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.3, random_state=0)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
#print(test.shape, target_test.shape)

#验证集
clf = clf.fit(X_train, y_train)
#clf = clf.fit(X_train, y_train,plot=True)
print('=======')
y_true, y_pred = y_test, clf.predict(X_test)
#print(y_pred)
print(classification_report(y_true, y_pred))
print("RandomForest:", clf.score(X_test, y_test))
print('=======')

#print(clf.predict(X_test))

#设定阈值
threshold = 0.53

predicted_proba = clf.predict_proba(X_test)
print(predicted_proba.shape)
predicted = (predicted_proba [:,1] >= threshold).astype('int')#
accuracy = accuracy_score(y_test, predicted)
print(classification_report(y_test, predicted))
print("accuracy: ", accuracy)

pred_1d = predicted_proba[:,1].reshape(7030,)
y_test = y_test.reshape(7030,)
print(pred_1d.shape, y_test.shape)
print("AUC: ",roc_auc_score(y_true, pred_1d))


print(predicted.shape)
#predicted.reshape(9373,2)
data1 = predicted_proba.reshape(7030,2)

#print(train.shape, target.shape)
#print(test.shape, target_test.shape)
# Out:
# (16402, 71) (16402,)
# (7030, 71) (7030,)
# 0:	learn: 0.3530109	total: 85.8ms	remaining: 25.7s
# 1:	learn: 0.2503239	total: 172ms	remaining: 25.6s
# 2:	learn: 0.2160994	total: 257ms	remaining: 25.4s
# 3:	learn: 0.1965159	total: 347ms	remaining: 25.6s
# 4:	learn: 0.1858454	total: 430ms	remaining: 25.3s
# 5:	learn: 0.1768568	total: 515ms	remaining: 25.2s
# 6:	learn: 0.1686457	total: 604ms	remaining: 25.3s
# 7:	learn: 0.1609422	total: 689ms	remaining: 25.2s
# 8:	learn: 0.1559310	total: 774ms	remaining: 25s
# 9:	learn: 0.1511262	total: 855ms	remaining: 24.8s
# 10:	learn: 0.1467540	total: 940ms	remaining: 24.7s
# 11:	learn: 0.1418478	total: 1.02s	remaining: 24.6s
# 12:	learn: 0.1346548	total: 1.11s	remaining: 24.6s
# 13:	learn: 0.1301569	total: 1.2s	remaining: 24.5s
# 14:	learn: 0.1247162	total: 1.28s	remaining: 24.4s
# 15:	learn: 0.1213498	total: 1.38s	remaining: 24.5s
# 16:	learn: 0.1188185	total: 1.46s	remaining: 24.3s
# 17:	learn: 0.1156532	total: 1.54s	remaining: 24.1s
# ...

# %%
def find_repeat_data(name_list):
    """
    查找列表中重复的数据
    :param name_list: 
    :return: 一个重复数据的列表，列表中字典的key 是重复的数据，value 是重复的次数
    """
    repeat_list = []
    for i in set(name_list):
        ret=name_list.count(i) # 查找该数据在原列表中的个数
        if ret > 1:
            item=dict()
            item[i] = ret
            repeat_list.append(item)
    print(repeat_list)
    return repeat_list

find_repeat_data(list(y_test))
find_repeat_data(list(predicted))
#find_repeat_data(list())
# Out:
# [{0: 6621}, {1: 409}]
# [{0: 6889}, {1: 141}]
# [{0: 6889}, {1: 141}]

# %%
print(type(data1))
print(data1.shape)
print(pred_1d.shape)
#print(data2)
df = pd.DataFrame(data1)
df.insert(2, 'answer', list(y_test))  # 2表示插入列的位置（索引）， 'answer'是列标题
print(type(df))
print(df)
#df.to_csv('output_classifier.csv')
# Out:
# <class 'numpy.ndarray'>
# (7030, 2)
# (7030,)
# <class 'pandas.core.frame.DataFrame'>
#              0         1  answer
# 0     0.979564  0.020436       0
# 1     0.996137  0.003863       0
# 2     0.999736  0.000264       0
# 3     0.999009  0.000991       0
# 4     0.980867  0.019133       0
# 5     0.996774  0.003226       0
# 6     0.999462  0.000538       0
# 7     0.999720  0.000280       0
# 8     0.999994  0.000006       0
# 9     0.991973  0.008027       0
# 10    0.742269  0.257731       1
# 11    0.998691  0.001309       0
# 12    0.998443  0.001557       0
# 13    0.999072  0.000928       0
# 14    0.978112  0.021888       0
# 15    0.999966  0.000034       0
# 16    0.997854  0.002146       0
# 17    0.996446  0.003554       0
# 18    0.999064  0.000936       0
# 19    0.999744  0.000256       0
# 20    0.996967  0.003033       0
# 21    0.999353  0.000647       0
# 22    0.989301  0.010699       0
# 23    0.999986  0.000014       0
# 24    0.762564  0.237436       0
# ...
