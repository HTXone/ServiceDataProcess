# %%
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

#train_data_file = './train_data02.csv'
#train_data_file = './feature_importance/train_data_50.csv'
#train_data_file = './feature_importance/train_twoStep_50.csv'
train_data_file = 'D:/QQFILE/Server_User_model/dataset/trainFinal2_del.csv'
test_data_file = 'D:/QQFILE/Server_User_model/dataset/val_Final_data2.csv'
train_data = pd.read_csv(train_data_file, encoding='utf-8')
test_data = pd.read_csv(test_data_file, encoding='utf-8')

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', 10)
print(train_data.shape)
print(test_data.shape)
#print(test_data.shape)
train_data.head()
#print(train_data['dist_cnt_y1'].isnull().sum())
# Out:
# (23432, 154)
# (6675, 154)
#    pax_fcny  pax_tax  tkt_3y_amt  dist_cnt_y1  dist_cnt_y3  avg_dist_cnt_y2  \
# 0    2497.0   5059.0         3.0          NaN          NaN              NaN
# 1    1494.0   1544.0         3.0          NaN          NaN            835.0
# 2     214.0   2689.0         3.0          NaN          NaN              NaN
# 3    1287.0   4452.0      3644.0        391.0        947.0           2925.0
# 4     645.0   2287.0      3682.0          NaN       1588.0              NaN
#
#    tkt_avg_amt_y3  dist_i_cnt_y3  avg_dist_cnt_y3  pref_city_y3_3  \
# 0             3.0            NaN              NaN             NaN
# 1          5452.0            NaN            875.0             NaN
# 2             3.0            NaN              NaN             NaN
# 3          5925.0          573.0           3380.0             NaN
# 4             3.0          948.0              NaN            59.0
#
#    tkt_avg_amt_y2  tkt_i_amt_y3  pref_city_y3_2  dist_i_cnt_y2  \
# 0             4.0           3.0             NaN            NaN
# 1          4599.0        4642.0             NaN            NaN
# 2             4.0           3.0             NaN            NaN
# 3             4.0        4669.0            62.0            NaN
# 4             4.0           3.0            49.0          865.0
#
#    seat_walkway_cnt_y3  dist_all_cnt_y2  pref_month_y3_1  pref_city_y2_2  \
# 0                  NaN              NaN              NaN             NaN
# 1                  NaN              NaN              2.0             NaN
# 2                  NaN              NaN              NaN             NaN
# 3                  1.0              NaN             12.0             NaN
# 4                  4.0           1533.0              NaN            49.0
#
#    pref_line_y3_3  pref_city_y2_3  tkt_all_amt_y3  avg_dist_cnt_y1  \
# 0             NaN             NaN             3.0              NaN
# 1           264.0             NaN          4722.0           1051.0
# 2             NaN             NaN             3.0              NaN
# 3             NaN             NaN          4594.0              NaN
# 4             NaN            57.0             3.0              NaN
#
#    pref_month_y3_2  pref_line_y2_2  pref_line_y3_1  prebuy_i_cnt_y3_d99  \
# 0              NaN             NaN             NaN                  NaN
# 1              4.0           332.0           306.0                  NaN
# 2              NaN             NaN             NaN                  NaN
# 3              1.0             NaN            99.0                  2.0
# 4              NaN             NaN             NaN                  4.0
#
#    pref_line_y3_4  pref_line_y3_2  seg_route_to  ffp_nbr  pref_orig_y3_3  \
# 0             NaN             NaN           NaN      NaN             NaN
# 1             NaN           340.0           NaN      NaN            54.0
# 2             NaN             NaN           1.0      NaN             NaN
# 3             NaN           244.0           1.0      NaN             NaN
# 4             NaN             NaN           NaN     11.0             NaN
#
#    flt_bag_cnt_y3  tkt_i_amt_y2  seat_middle_cnt_y3  pref_line_y2_1  \
# 0             NaN           4.0                 NaN             NaN
# 1             NaN        3772.0                 NaN           305.0
# 2             NaN           4.0                 NaN             NaN
# 3             2.0           4.0                 NaN             NaN
# 4             4.0           4.0                 NaN             NaN
#
#    seat_window_cnt_y3  pref_orig_city_y2  pref_month_y2_1  pref_line_y2_3  \
# 0                 NaN                NaN              NaN             NaN
# 1                 2.0                NaN              2.0           238.0
# 2                 NaN                NaN              NaN             NaN
# 3                 1.0                NaN              NaN             NaN
# 4                 NaN               79.0              NaN             NaN
#
#    pref_line_y2_4  pref_month_y2_2  pref_month_y3_3  pref_orig_y3_2  \
# 0             NaN              NaN              NaN             NaN
# 1             NaN              4.0              NaN            52.0
# 2             NaN              NaN              NaN             NaN
# 3             NaN              NaN              NaN            62.0
# 4             NaN              NaN              NaN             NaN
#
#    tkt_all_amt_y2  age  flt_delay_time_m3  flt_delay_cnt_y3  pref_city_y1_2  \
# 0             4.0  NaN              833.0               NaN             NaN
# 1          3860.0  NaN              833.0               NaN             NaN
# 2             4.0  NaN              833.0               NaN             NaN
# 3             4.0  NaN              833.0               NaN             NaN
# 4             4.0  NaN              833.0               NaN             NaN
#
#    pref_city_y3_4  prebuy_i_cnt_y2_d99  pit_avg_amt_y3  seat_walkway_cnt_y2  \
# 0             NaN                  NaN             NaN                  NaN
# 1             NaN                  NaN             NaN                  NaN
# 2             NaN                  NaN             NaN                  NaN
# 3             NaN                  NaN             NaN                  NaN
# 4             NaN                  4.0             NaN                  4.0
#
#    nation_name  pref_orig_y2_2  pref_month_y2_3  flt_bag_cnt_y2  \
# 0          NaN             NaN              NaN             NaN
# 1          NaN            52.0              NaN             NaN
# 2          NaN             NaN              NaN             NaN
# 3          NaN             NaN              NaN             NaN
# 4          NaN             NaN              NaN             4.0
#
#    pref_month_y3_4  pit_all_amt  pit_avg_amt_y2  pit_accu_air_amt  \
# 0              NaN          7.0             NaN               NaN
# 1              NaN          7.0             NaN               NaN
# 2              NaN          7.0             NaN               NaN
# 3              NaN          7.0             NaN               NaN
# 4              NaN          7.0             NaN               NaN
#
#    cabin_y_cnt_y3  cabin_hy_cnt_y3  pref_line_y1_2  pit_next_level_dist  \
# 0             NaN              NaN             NaN                  2.0
# 1             NaN              NaN           196.0                  2.0
# 2             NaN              NaN             NaN                  2.0
# 3             2.0              NaN             NaN                  2.0
# 4             NaN              NaN             NaN                  2.0
#
#    flt_nature_cnt_y1  pref_city_y2_4  dist_all_cnt_y1  pref_orig_y2_3  \
# 0                NaN             NaN              NaN             NaN
# 1                NaN             NaN              NaN            54.0
# 2                NaN             NaN              NaN             NaN
# 3                1.0             NaN              NaN             NaN
# 4                NaN             NaN              NaN             NaN
#
#    dist_d_cnt_y3  pit_avg_accu_amt_y3  tkt_avg_amt_y1  flt_delay_time_y2  \
# 0            NaN                  NaN             NaN              612.0
# 1           80.0                  NaN          2094.0              612.0
# 2            NaN                  NaN             NaN              612.0
# 3            NaN                  NaN             NaN              612.0
# 4            NaN                  NaN             NaN              612.0
#
#    pit_avg_interval_y2  pref_city_y1_1  pref_line_y3_5  mdl_mcv  \
# 0                  NaN             NaN             NaN      NaN
# 1                  NaN             NaN             NaN      5.0
# 2                  NaN             NaN             NaN      NaN
# 3                  NaN             NaN             NaN      5.0
# 4                  NaN             NaN             NaN      NaN
#
#    dist_i_cnt_y1  dist_all_cnt_y3  pit_accu_air_cnt  gender  tkt_book_cnt_y3  \
# 0            NaN              NaN               NaN     NaN              NaN
# 1            NaN              NaN               NaN     NaN              NaN
# 2            NaN              NaN               NaN     NaN              NaN
# 3            NaN            947.0               NaN     NaN              NaN
# 4            NaN           1588.0               NaN     2.0              NaN
#
#    mdl_influence  flt_nature_cnt_y3  seat_middle_cnt_y2  select_seat_cnt_y2  \
# 0            NaN                NaN                 NaN                 NaN
# 1            NaN                NaN                 NaN                 NaN
# 2            NaN                NaN                 NaN                 NaN
# 3            NaN                2.0                 NaN                 NaN
# 4            NaN                4.0                 NaN                 NaN
#
#    flt_leg_i_cnt_y3  avg_dist_cnt_m6  tkt_d_amt_y3  pref_city_y1_3  \
# 0               NaN              NaN           NaN             NaN
# 1               NaN              NaN        1124.0             NaN
# 2               NaN              NaN           NaN             NaN
# 3               2.0              NaN           NaN             NaN
# 4               4.0              NaN           NaN             NaN
#
#    pref_month_y3_5  cabin_y_cnt_y2  pref_orig_city_y3  pit_accu_amt_y3  \
# 0              NaN             NaN                NaN              NaN
# 1              NaN             NaN                NaN              NaN
# 2              NaN             NaN                NaN              NaN
# 3              NaN             NaN               50.0              NaN
# 4              NaN             NaN               77.0              NaN
#
#    prebuy_i_cnt_y3_d30  prebuy_i_cnt_y3_d3  flt_delay_time_m6  \
# 0                  NaN                 NaN              799.0
# 1                  NaN                 NaN              799.0
# 2                  NaN                 NaN              799.0
# 3                  NaN                 NaN              799.0
# 4                  NaN                 NaN              799.0
#
#    pref_month_y2_4  prebuy_d_cnt_y3_d99  pit_accu_amt_y2  pit_avg_interval_y3  \
# 0              NaN                  NaN              NaN                  NaN
# 1              NaN                  NaN              NaN                  NaN
# 2              NaN                  NaN              NaN                  NaN
# 3              NaN                  NaN              NaN                  NaN
# 4              NaN                  NaN              NaN                  NaN
#
#    seg_cabin  tkt_avg_interval_y3  flt_delay_time_y3  pref_month_y1_1  \
# 0        2.0                  NaN                NaN              NaN
# 1        2.0                  NaN                NaN              2.0
# 2        4.0                  NaN                NaN              NaN
# 3        4.0                  NaN                NaN              NaN
# 4        4.0                  NaN                NaN              NaN
#
#    dist_i_cnt_m6  pref_line_y1_3  pit_add_air_amt_y3  pref_month_y2_5  \
# 0            NaN             NaN                 NaN              NaN
# 1            NaN             NaN                 NaN              NaN
# 2            NaN             NaN                 NaN              NaN
# 3            NaN             NaN                 NaN              NaN
# 4            NaN             NaN                 NaN              NaN
#
#    flt_leg_cnt_y2  pit_accu_amt_y1  flt_delay_cnt_y2  pit_avg_accu_amt_y2  \
# 0             NaN              NaN               NaN                  NaN
# 1             NaN              NaN               NaN                  NaN
# 2             NaN              NaN               NaN                  NaN
# 3             NaN              NaN               NaN                  NaN
# 4             4.0              NaN               NaN                  NaN
#
#    pref_city_y3_1  dist_all_cnt_m6  seat_window_cnt_y2  flt_cnt_y3  \
# 0             NaN              NaN                 NaN         NaN
# 1             NaN              NaN                 2.0         3.0
# 2             NaN              NaN                 NaN         NaN
# 3            46.0              NaN                 NaN         2.0
# 4            46.0              NaN                 NaN         NaN
#
#    pref_line_y1_1  pref_orig_y3_1  flt_bag_cnt_y1  flt_leg_i_cnt_y2  \
# 0             NaN             NaN             NaN               NaN
# 1           271.0            44.0             NaN               NaN
# 2             NaN             NaN             NaN               NaN
# 3             NaN            44.0             NaN               NaN
# 4             NaN             NaN             NaN               4.0
#
#    prebuy_d_cnt_y2_d99  tkt_d_amt_y2  flt_delay_time_y1  tkt_avg_interval_y2  \
# 0                  NaN           1.0              774.0                  NaN
# 1                  NaN         932.0              774.0                  NaN
# 2                  NaN           1.0              774.0                  NaN
# 3                  NaN           1.0              774.0                  NaN
# 4                  NaN           1.0              774.0                  NaN
#
#    dist_d_cnt_y2  pref_orig_y1_1  cabin_hy_cnt_y2  pref_orig_city_y1  \
# 0            NaN             NaN              NaN                NaN
# 1           78.0            52.0              NaN                NaN
# 2            NaN             NaN              NaN                NaN
# 3            NaN             NaN              NaN                NaN
# 4            NaN             NaN              NaN                NaN
#
#    cabin_hf_cnt_m6  pref_orig_y3_4  pref_dest_city_y3  pit_accu_non_amt  \
# 0              NaN             NaN                NaN               NaN
# 1              NaN             NaN               54.0               NaN
# 2              NaN             NaN                NaN               NaN
# 3              NaN             NaN               43.0               NaN
# 4              NaN             NaN                NaN               NaN
#
#    tkt_book_cnt_y2  tkt_i_amt_y1  pref_city_y2_5  tkt_all_amt_y1  \
# 0              NaN           NaN             NaN             NaN
# 1              NaN        1524.0             NaN          1609.0
# 2              NaN           NaN             NaN             NaN
# 3              NaN           NaN             NaN             NaN
# 4              NaN           NaN             NaN             NaN
#
#    pref_city_y2_1  residence_country  pref_orig_y2_4  pit_add_air_amt_y2  \
# 0             NaN                NaN             NaN                 NaN
# 1             NaN                NaN             NaN                 NaN
# 2             NaN                NaN             NaN                 NaN
# 3             NaN                NaN             NaN                 NaN
# 4            51.0                1.0             NaN                 NaN
#
#    prebuy_i_cnt_y3_d14  pref_orig_y1_2  tkt_return_cnt_y3  \
# 0                  NaN             NaN                NaN
# 1                  NaN            45.0                NaN
# 2                  NaN             NaN                NaN
# 3                  NaN             NaN                NaN
# 4                  NaN             NaN                NaN
#
#    pit_avg_accu_amt_y1  pref_line_y2_5  pit_cons_amt_y3  prebuy_i_cnt_y2_d30  \
# 0                  NaN             NaN              NaN                  NaN
# 1                  NaN             NaN              NaN                  NaN
# 2                  NaN             NaN              NaN                  NaN
# 3                  NaN             NaN              NaN                  NaN
# 4                  NaN             NaN              NaN                  NaN
#
#    pref_orig_y3_5  pit_avg_amt_y1  pref_orig_city_m6  emd_lable2  emd_lable  \
# 0             NaN             NaN                NaN           0          0
# 1             NaN             NaN                NaN           0          1
# 2             NaN             NaN                NaN           0          1
# 3             NaN             NaN                NaN           0          0
# 4             NaN             NaN                NaN           1          1
#
#                            pax_name                      pax_passport
# 0  9612c51f08718e48b1361e415ef55be9  93d0aceeaef3f85264e5c5b5b1148a90
# 1  c7ca533cd9da4c4bf3d597248f90bc6e  6930f6fa59d86c11fa28c610ab6f56a5
# 2  bd2cb6b0dd56fb3de6f7c018296a07e2  da73afa8f6ededd29d67a9331dccdbe9
# 3  65657872fe131ea7651565638dcb5683  dc31eead23771810dbb586ad236ade3b
# 4  722261f7b860b183da9fe0b6630b6dbf  7689603247539830a08d945cb1a57823

# %%
#train_data['dist_cnt_y1'].replace(0, '', inplace = True)
features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable', 'emd_lable2']]
#features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable2']]
#features_columns_test = [col for col in test_data.columns ]
# print(Data.shape)

train = train_data[features_columns].values
target =train_data['emd_lable2'].values
# target2 =train_data['emd_lable'].values

# %%
from sklearn.feature_selection import SelectKBest
from array import array
from sklearn.feature_selection import chi2
SB = SelectKBest(chi2, k=71)
train = SB.fit_transform(train, target)
print(SB.get_support(indices = True))
print(train.shape)

train = pd.DataFrame(train)
train.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-1423d232ede1> in <module>
#       3 from sklearn.feature_selection import chi2
#       4 SB = SelectKBest(chi2, k=71)
# ----> 5 train = SB.fit_transform(train, target)
#       6 print(SB.get_support(indices = True))
#       7 print(train.shape)
#
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
# --> 702             return self.fit(X, y, **fit_params).transform(X)
#     703
#     704
#
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     342         """
#     343         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
# --> 344                                    multi_output=True)
#     345
#     346         if not callable(self.score_func):
#
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     819                     ensure_min_samples=ensure_min_samples,
#     820                     ensure_min_features=ensure_min_features,
# --> 821                     estimator=estimator)
#     822     if multi_output:
#     823         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     662         if force_all_finite:
#     663             _assert_all_finite(array,
# --> 664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#     666     if ensure_min_samples > 0:
#
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     104                     msg_err.format
#     105                     (type_err,
# --> 106                      msg_dtype if msg_dtype is not None else X.dtype)
#     107             )
#     108     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.3, random_state=0)
print(X_train.shape,y_train.shape,y_test.shape)
# Out:
# (16402, 150) (16402,) (7030,)

# %%
y_train = y_train.reshape((16402,1))
# y_train = y_train.reshape((16402,1))
z = np.zeros(7030)
z = z.reshape(7030,1)
Data = X_train
Data = np.hstack((X_train,y_train))
Data2 = np.hstack((X_test,z))
print(Data.shape,Data2.shape)
for i in range(len(Data2)):
    Data2[i][150] = float('nan')
print(Data.shape,Data2.shape)
# Out:
# (16402, 151) (7030, 151)
# (16402, 151) (7030, 151)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer()
imp.fit(Data,None)
Data = imp.transform(Data)
Data2 = imp.transform(Data2)
# train_data[category_fea] = Data
#train_data.head()
#按照平均数填充数值型特征
# for col in numerical_fea:
#     List = train_data[col]
#     List2 = []
#     for i in List:
#         if i == i:
#             List2.append(i)
#     List2 = np.array(List2)
#     from scipy import stats
#     x = stats.mode(List2)[0][0]
#     train_data[col] = train_data[col].fillna(x)
    
#     train_data[numerical_fea] = train_data[numerical_fea].fillna(train_data[numerical_fea].median())
#data_test_a[numerical_fea] = data_test_a[numerical_fea].fillna(data_train[numerical_fea].median())

#按照众数填充类别型特征
# train_data[category_fea] = train_data[category_fea].fillna(train_data[category_fea].median())
#data_test_a[category_fea] = data_test_a[category_fea].fillna(data_train[category_fea].mode())
# Out:
# D:\anaconda\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:686: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)

# %%
features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable', 'emd_lable2']]
#features_columns = [col for col in train_data.columns if col not in ['pax_name', 'pax_passport', 'emd_lable2']]
#features_columns_test = [col for col in test_data.columns ]
# print(Data.shape)
# train = Data
# target =train_data['emd_lable2'].values

print(Data.shape)
print(Data2.shape)
# print(train_data[features_columns].values.shape)
# print(target.sum())

for i in range(len(Data)):
    for j in range(150):
        if train[i][j]<0:
            train[i][j] = 0
            
for i in range(len(Data2)):
    for j in range(150):
        if train[i][j]<0:
            train[i][j] = 0
X_train = Data[:,:-1]
X_test = Data2[:,:-1]
# Out:
# (16402, 151)
# (7030, 151)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (16402, 150) (7030, 150)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

clf = RandomForestClassifier(n_estimators=500, 
                             max_depth=71, 
                             random_state=0, 
                             n_jobs=-1)
# from catboost import CatBoostClassifier
# clf = CatBoostClassifier(iterations=300,
#                 depth=12,
#                 random_seed=0,
#                 thread_count=-1,
#                 learning_rate = 0.4,
#                 task_type="GPU",
#                 loss_function = "CrossEntropy",
#                 #nan_mode= "Max"
#             )




print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
#print(test.shape, target_test.shape)

#验证集
clf = clf.fit(X_train, y_train)
#clf = clf.fit(X_train, y_train,plot=True)
print('=======')
y_true, y_pred = y_test, clf.predict(X_test)
#print(y_pred)
print(classification_report(y_true, y_pred))
print("RandomForest:", clf.score(X_test, y_test))
print('=======')

#print(clf.predict(X_test))

#设定阈值
threshold = 0.53

predicted_proba = clf.predict_proba(X_test)
print(predicted_proba.shape)
predicted = (predicted_proba [:,1] >= threshold).astype('int')#
accuracy = accuracy_score(y_test, predicted)
print(classification_report(y_test, predicted))
print("accuracy: ", accuracy)

pred_1d = predicted_proba[:,1].reshape(7030,)
y_test = y_test.reshape(7030,)
print(pred_1d.shape, y_test.shape)
print("AUC: ",roc_auc_score(y_true, pred_1d))


print(predicted.shape)
#predicted.reshape(9373,2)
data1 = predicted_proba.reshape(7030,2)

#print(train.shape, target.shape)
#print(test.shape, target_test.shape)
# Out:
# (16402, 150) (16402, 1)
# (7030, 150) (7030,)
# D:\anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# =======
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6621
#            1       0.55      0.03      0.06       409
#
#     accuracy                           0.94      7030
#    macro avg       0.74      0.51      0.51      7030
# weighted avg       0.92      0.94      0.92      7030
#
# RandomForest: 0.9421052631578948
# =======
# (7030, 2)
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6621
#            1       0.58      0.03      0.05       409
#
#     accuracy                           0.94      7030
#    macro avg       0.76      0.51      0.51      7030
# weighted avg       0.92      0.94      0.92      7030
#
# accuracy:  0.9422475106685633
# (7030,) (7030,)
# AUC:  0.6224678165236269
# (7030,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# clf = RandomForestClassifier(n_estimators=500, 
#                              max_depth=71, 
#                              random_state=0, 
#                              n_jobs=-1)
from catboost import CatBoostClassifier
clf = CatBoostClassifier(iterations=300,
                depth=12,
                random_seed=0,
                thread_count=-1,
                learning_rate = 0.4,
                task_type="GPU",
                loss_function = "CrossEntropy",
                #nan_mode= "Max"
            )


X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.3, random_state=0)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
#print(test.shape, target_test.shape)

#验证集
clf = clf.fit(X_train, y_train)
#clf = clf.fit(X_train, y_train,plot=True)
print('=======')
y_true, y_pred = y_test, clf.predict(X_test)
#print(y_pred)
print(classification_report(y_true, y_pred))
print("RandomForest:", clf.score(X_test, y_test))
print('=======')

#print(clf.predict(X_test))

#设定阈值
threshold = 0.53

predicted_proba = clf.predict_proba(X_test)
print(predicted_proba.shape)
predicted = (predicted_proba [:,1] >= threshold).astype('int')#
accuracy = accuracy_score(y_test, predicted)
print(classification_report(y_test, predicted))
print("accuracy: ", accuracy)

pred_1d = predicted_proba[:,1].reshape(7030,)
y_test = y_test.reshape(7030,)
print(pred_1d.shape, y_test.shape)
print("AUC: ",roc_auc_score(y_true, pred_1d))


print(predicted.shape)
#predicted.reshape(9373,2)
data1 = predicted_proba.reshape(7030,2)

#print(train.shape, target.shape)
#print(test.shape, target_test.shape)
# Out:
# (16402, 150) (16402,)
# (7030, 150) (7030,)
# 0:	learn: 0.3527107	total: 130ms	remaining: 38.9s
# 1:	learn: 0.2521094	total: 236ms	remaining: 35.1s
# 2:	learn: 0.2209783	total: 346ms	remaining: 34.3s
# 3:	learn: 0.2038524	total: 469ms	remaining: 34.7s
# 4:	learn: 0.1944192	total: 587ms	remaining: 34.7s
# 5:	learn: 0.1886702	total: 703ms	remaining: 34.4s
# 6:	learn: 0.1815571	total: 812ms	remaining: 34s
# 7:	learn: 0.1765939	total: 919ms	remaining: 33.6s
# 8:	learn: 0.1707235	total: 1.03s	remaining: 33.2s
# 9:	learn: 0.1675339	total: 1.14s	remaining: 32.9s
# 10:	learn: 0.1643776	total: 1.24s	remaining: 32.6s
# 11:	learn: 0.1624418	total: 1.34s	remaining: 32.3s
# 12:	learn: 0.1614763	total: 1.44s	remaining: 31.8s
# 13:	learn: 0.1567084	total: 1.57s	remaining: 32s
# 14:	learn: 0.1543084	total: 1.67s	remaining: 31.8s
# 15:	learn: 0.1523872	total: 1.78s	remaining: 31.6s
# 16:	learn: 0.1500335	total: 1.88s	remaining: 31.3s
# 17:	learn: 0.1464096	total: 2s	remaining: 31.4s
# 162:	learn: 0.0403525	total: 17.3s	remaining: 14.5s
# 163:	learn: 0.0401442	total: 17.4s	remaining: 14.4s
# 164:	learn: 0.0398969	total: 17.5s	remaining: 14.3s
# 165:	learn: 0.0396409	total: 17.6s	remaining: 14.2s
# 166:	learn: 0.0394501	total: 17.7s	remaining: 14.1s
# 167:	learn: 0.0392880	total: 17.8s	remaining: 14s
# 168:	learn: 0.0390758	total: 17.9s	remaining: 13.9s
# 169:	learn: 0.0388508	total: 18s	remaining: 13.8s
# 170:	learn: 0.0386906	total: 18.1s	remaining: 13.7s
# 171:	learn: 0.0384336	total: 18.2s	remaining: 13.5s
# 172:	learn: 0.0382461	total: 18.3s	remaining: 13.4s
# 173:	learn: 0.0381356	total: 18.4s	remaining: 13.3s
# 174:	learn: 0.0378753	total: 18.5s	remaining: 13.2s
# 175:	learn: 0.0376393	total: 18.6s	remaining: 13.1s
# 176:	learn: 0.0375051	total: 18.7s	remaining: 13s
# 177:	learn: 0.0373598	total: 18.8s	remaining: 12.9s
# 178:	learn: 0.0371796	total: 18.9s	remaining: 12.8s
# 179:	learn: 0.0371227	total: 19s	remaining: 12.7s
# 180:	learn: 0.0368759	total: 19.1s	remaining: 12.6s
# 181:	learn: 0.0367086	total: 19.2s	remaining: 12.5s
# 182:	learn: 0.0366134	total: 19.3s	remaining: 12.4s
# 183:	learn: 0.0364821	total: 19.4s	remaining: 12.3s
# 184:	learn: 0.0363130	total: 19.5s	remaining: 12.2s
# 185:	learn: 0.0361929	total: 19.6s	remaining: 12s
# 186:	learn: 0.0360430	total: 19.7s	remaining: 11.9s
# 187:	learn: 0.0359279	total: 19.9s	remaining: 11.8s
# 188:	learn: 0.0358764	total: 20s	remaining: 11.7s
# 189:	learn: 0.0358344	total: 20.1s	remaining: 11.6s
# 190:	learn: 0.0357456	total: 20.2s	remaining: 11.5s
# 191:	learn: 0.0355383	total: 20.3s	remaining: 11.4s
# 192:	learn: 0.0353085	total: 20.4s	remaining: 11.3s
# 193:	learn: 0.0352029	total: 20.5s	remaining: 11.2s
# 194:	learn: 0.0349481	total: 20.6s	remaining: 11.1s
# 195:	learn: 0.0347456	total: 20.7s	remaining: 11s
# 196:	learn: 0.0346089	total: 20.8s	remaining: 10.9s
# 197:	learn: 0.0344917	total: 20.9s	remaining: 10.8s
# 198:	learn: 0.0343795	total: 21s	remaining: 10.7s
# 199:	learn: 0.0342343	total: 21.1s	remaining: 10.5s
# 200:	learn: 0.0340812	total: 21.2s	remaining: 10.4s
# 201:	learn: 0.0339394	total: 21.3s	remaining: 10.3s
# 202:	learn: 0.0337997	total: 21.4s	remaining: 10.2s
# 203:	learn: 0.0336431	total: 21.5s	remaining: 10.1s
# 204:	learn: 0.0333833	total: 21.6s	remaining: 10s
# 205:	learn: 0.0333213	total: 21.7s	remaining: 9.91s
# 206:	learn: 0.0331114	total: 21.8s	remaining: 9.81s
# 207:	learn: 0.0330142	total: 21.9s	remaining: 9.7s
# 208:	learn: 0.0329577	total: 22s	remaining: 9.6s
# 209:	learn: 0.0328698	total: 22.1s	remaining: 9.49s
# 258:	learn: 0.0277894	total: 27.2s	remaining: 4.31s
# 259:	learn: 0.0276514	total: 27.4s	remaining: 4.21s
# 260:	learn: 0.0275755	total: 27.5s	remaining: 4.1s
# 261:	learn: 0.0275396	total: 27.6s	remaining: 4s
# 262:	learn: 0.0274727	total: 27.7s	remaining: 3.89s
# 263:	learn: 0.0273368	total: 27.8s	remaining: 3.79s
# 264:	learn: 0.0272641	total: 27.9s	remaining: 3.68s
# 265:	learn: 0.0271751	total: 28s	remaining: 3.57s
# 266:	learn: 0.0271046	total: 28.1s	remaining: 3.47s
# 267:	learn: 0.0270245	total: 28.2s	remaining: 3.36s
# 268:	learn: 0.0269311	total: 28.3s	remaining: 3.26s
# 269:	learn: 0.0268103	total: 28.4s	remaining: 3.15s
# 270:	learn: 0.0267598	total: 28.5s	remaining: 3.05s
# 271:	learn: 0.0266821	total: 28.6s	remaining: 2.94s
# 272:	learn: 0.0266245	total: 28.7s	remaining: 2.84s
# 273:	learn: 0.0265397	total: 28.8s	remaining: 2.73s
# 274:	learn: 0.0264867	total: 28.9s	remaining: 2.63s
# 275:	learn: 0.0264522	total: 29s	remaining: 2.52s
# 276:	learn: 0.0263552	total: 29.1s	remaining: 2.42s
# 277:	learn: 0.0262799	total: 29.2s	remaining: 2.31s
# 278:	learn: 0.0262120	total: 29.3s	remaining: 2.21s
# 279:	learn: 0.0261409	total: 29.4s	remaining: 2.1s
# 280:	learn: 0.0261072	total: 29.5s	remaining: 2s
# 281:	learn: 0.0260258	total: 29.6s	remaining: 1.89s
# 282:	learn: 0.0259622	total: 29.7s	remaining: 1.79s
# 283:	learn: 0.0259296	total: 29.8s	remaining: 1.68s
# 284:	learn: 0.0259120	total: 29.9s	remaining: 1.58s
# 285:	learn: 0.0258445	total: 30.1s	remaining: 1.47s
# 286:	learn: 0.0258151	total: 30.2s	remaining: 1.37s
# 287:	learn: 0.0257432	total: 30.3s	remaining: 1.26s
# 288:	learn: 0.0256679	total: 30.4s	remaining: 1.16s
# 289:	learn: 0.0255797	total: 30.5s	remaining: 1.05s
# 290:	learn: 0.0255228	total: 30.6s	remaining: 946ms
# 291:	learn: 0.0254618	total: 30.7s	remaining: 841ms
# 292:	learn: 0.0254413	total: 30.8s	remaining: 736ms
# 293:	learn: 0.0253527	total: 30.9s	remaining: 631ms
# 294:	learn: 0.0253309	total: 31s	remaining: 525ms
# 295:	learn: 0.0252606	total: 31.1s	remaining: 420ms
# 296:	learn: 0.0252467	total: 31.2s	remaining: 315ms
# 297:	learn: 0.0252020	total: 31.3s	remaining: 210ms
# 298:	learn: 0.0251580	total: 31.4s	remaining: 105ms
# 299:	learn: 0.0251384	total: 31.5s	remaining: 0us
# =======
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6621
#            1       0.53      0.21      0.30       409
#
#     accuracy                           0.94      7030
#    macro avg       0.74      0.60      0.63      7030
# weighted avg       0.93      0.94      0.93      7030
#
# RandomForest: 0.9433854907539118
# =======
# (7030, 2)
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6621
#            1       0.55      0.20      0.29       409
#
#     accuracy                           0.94      7030
#    macro avg       0.75      0.60      0.63      7030
# weighted avg       0.93      0.94      0.93      7030
#
# accuracy:  0.9438122332859175
# (7030,) (7030,)
# AUC:  0.7909712705627682
# (7030,)

# %%
def find_repeat_data(name_list):
    """
    查找列表中重复的数据
    :param name_list: 
    :return: 一个重复数据的列表，列表中字典的key 是重复的数据，value 是重复的次数
    """
    repeat_list = []
    for i in set(name_list):
        ret=name_list.count(i) # 查找该数据在原列表中的个数
        if ret > 1:
            item=dict()
            item[i] = ret
            repeat_list.append(item)
    print(repeat_list)
    return repeat_list

find_repeat_data(list(y_test))
find_repeat_data(list(predicted))
#find_repeat_data(list())
# Out:
# [{0: 6621}, {1: 409}]
# [{0: 6880}, {1: 150}]
# [{0: 6880}, {1: 150}]

# %%
print(type(data1))
print(data1.shape)
print(pred_1d.shape)
#print(data2)
df = pd.DataFrame(data1)
df.insert(2, 'answer', list(y_test))  # 2表示插入列的位置（索引）， 'answer'是列标题
print(type(df))
print(df)
#df.to_csv('output_classifier.csv')
# Out:
# <class 'numpy.ndarray'>
# (7030, 2)
# (7030,)
# <class 'pandas.core.frame.DataFrame'>
#              0         1  answer
# 0     0.999960  0.000040       0
# 1     0.930355  0.069645       0
# 2     0.999550  0.000450       0
# 3     0.999947  0.000053       0
# 4     0.993273  0.006727       0
# 5     0.923728  0.076272       0
# 6     0.995550  0.004450       0
# 7     0.975997  0.024003       0
# 8     0.999773  0.000227       0
# 9     0.989535  0.010465       0
# 10    0.890234  0.109766       1
# 11    0.994081  0.005919       0
# 12    0.991376  0.008624       0
# 13    0.997520  0.002480       0
# 14    0.996580  0.003420       0
# 15    0.999820  0.000180       0
# 16    0.995668  0.004332       0
# 17    0.999070  0.000930       0
# 18    0.991281  0.008719       0
# 19    0.999848  0.000152       0
# 20    0.995888  0.004112       0
# 21    0.997156  0.002844       0
# 22    0.999715  0.000285       0
# 23    0.999982  0.000018       0
# 24    0.951191  0.048809       0
# 25    0.999211  0.000789       0
# 26    0.994265  0.005735       0
# 27    0.999015  0.000985       0
# 28    0.997998  0.002002       0
# 29    0.999965  0.000035       0
# ...        ...       ...     ...
# 7000  0.997998  0.002002       0
# 7001  0.998493  0.001507       0
# 7002  0.999744  0.000256       0
# 7003  0.999251  0.000749       0
# 7004  0.993006  0.006994       0
# 7005  0.776094  0.223906       0
# 7006  0.989970  0.010030       0
# 7007  0.887184  0.112816       0
# 7008  0.994606  0.005394       0
# 7009  0.981452  0.018548       0
# 7010  0.948936  0.051064       0
# 7011  0.998888  0.001112       0
# 7012  0.991019  0.008981       0
# 7013  0.999705  0.000295       0
# 7014  0.999326  0.000674       0
# 7015  0.998924  0.001076       0
# 7016  0.082779  0.917221       1
# 7017  0.819356  0.180644       0
# 7018  0.994073  0.005927       0
# 7019  0.999272  0.000728       0
# 7020  0.999847  0.000153       0
# 7021  0.999725  0.000275       0
# 7022  0.999993  0.000007       0
# 7023  0.999740  0.000260       0
# 7024  0.999988  0.000012       0
# 7025  0.999980  0.000020       0
# 7026  0.999934  0.000066       0
# 7027  0.976363  0.023637       0
# 7028  0.997633  0.002367       0
# 7029  0.999977  0.000023       0
#
# [7030 rows x 3 columns]
